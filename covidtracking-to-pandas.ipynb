# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import json

# %%
https://covidtracking.com/api/states/daily

# %%
https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html

# %%
r = requests.get('https://covidtracking.com/api/states/daily')
data = r.json()
#pd.json_normalize(data['results'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2641add9b9e4> in <module>
#       1 r = requests.get('https://covidtracking.com/api/states/daily')
#       2 data = r.json()
# ----> 3 pd.json_normalize(data['results'])
#
# ~/anaconda37/envs/mh37d/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
pd.DataFrame(data)
# Out:
#           date state  positive  negative  pending  hospitalized  death  total  \
# 0     20200330    AK     114.0    3540.0      NaN           7.0    3.0   3654
# 1     20200330    AL     859.0    5694.0      NaN           NaN    6.0   6553
# 2     20200330    AR     473.0    5262.0      NaN          62.0    7.0   5735
# 3     20200330    AS       NaN       NaN      NaN           NaN    0.0      0
# 4     20200330    AZ    1157.0   15602.0      NaN          78.0   20.0  16759
# ...        ...   ...       ...       ...      ...           ...    ...    ...
# 1368  20200304    OR       3.0      29.0     18.0           NaN    NaN     50
# 1369  20200304    SC       0.0       5.0      0.0           NaN    NaN      5
# 1370  20200304    TX       1.0       NaN      NaN           NaN    NaN      1
# 1371  20200304    WA      39.0       NaN      NaN           NaN    NaN     39
# 1372  20200304    WI       1.0      19.0      6.0           NaN    NaN     26
#
#                                           hash           dateChecked  \
# 0     01a1c96fd2ed214d8747ab778c2fec7203c8cd2f  2020-03-30T20:00:00Z
# 1     1ced1dbd9879f8bbc4b1f7b7876b82611895d58e  2020-03-30T20:00:00Z
# 2     7199b3f9984cc54342a3d0f5926bff36ef440b6c  2020-03-30T20:00:00Z
# 3     955da7e53291581ad33f46d87bad7e4724848fea  2020-03-30T20:00:00Z
# 4     2f64421fc130d03c93a0fa1b89e44c0324ac15a3  2020-03-30T20:00:00Z
# ...                                        ...                   ...
# 1368  5b37d7f2e6aa9fb39e09270626674b16ce9b5182  2020-03-04T21:00:00Z
# 1369  992c7ca6f8259ac7a323c0b92c27123c671f3773  2020-03-04T21:00:00Z
# 1370  7be175c20e3c9485c14f9764bd90385842df19c3  2020-03-04T21:00:00Z
# 1371  36ea36bcf282dcc480c83b6f2561810b009bc951  2020-03-04T21:00:00Z
# 1372  0f8cc0d051348c50905a5d5b43ba3c5e23897523  2020-03-04T21:00:00Z
#
#       totalTestResults fips  deathIncrease  hospitalizedIncrease  \
# 0                 3654   02            1.0                   1.0
# 1                 6553   01            2.0                   0.0
# 2                 5735   05            1.0                  14.0
# 3                    0   60            0.0                   0.0
# 4                16759   04            3.0                   0.0
# ...                ...  ...            ...                   ...
# 1368                32   41            NaN                   NaN
# 1369                 5   45            NaN                   NaN
# 1370                 1   48            NaN                   NaN
# 1371                39   53            NaN                   NaN
# 1372                20   55            NaN                   NaN
#
#       negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0                308.0              12.0                     320.0
# 1               1510.0              53.0                    1563.0
# 2               2235.0              47.0                    2282.0
# 3                  0.0               0.0                       0.0
# 4               2649.0             238.0                    2887.0
# ...                ...               ...                       ...
# 1368               NaN               NaN                       NaN
# 1369               NaN               NaN                       NaN
# 1370               NaN               NaN                       NaN
# 1371               NaN               NaN                       NaN
# 1372               NaN               NaN                       NaN
#
# [1373 rows x 17 columns]
